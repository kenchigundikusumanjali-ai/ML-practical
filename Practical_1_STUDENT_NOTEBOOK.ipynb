# %% [markdown]
# <a href="https://colab.research.google.com/github/kenchigundikusumanjali-ai/ML_practical/blob/main/Practical_1_STUDENT_NOTEBOOK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

print("Python Version:", sys.version)
# Out:
# Python Version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
import numpy as np

print("NumPy Version:", np.__version__)
# Out:
# NumPy Version: 2.0.2

# %%
import pandas as pd

print("Pandas Version:", pd.__version__)
# Out:
# Pandas Version: 2.2.2

# %%
import matplotlib

print("Matplotlib Version:", matplotlib.__version__)
# Out:
# Matplotlib Version: 3.10.0

# %%
import sklearn

print("Scikit-learn Version:", sklearn.__version__)
# Out:
# Scikit-learn Version: 1.6.1

# %%
import pandas as pd

student = {
    "Name": ["Amit", "Priya", "Rahul"],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(student)
print(df)
# Out:
#     Name  Marks
# 0   Amit     85
# 1  Priya     90
# 2  Rahul     78

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 15, 30]

plt.plot(x, y)
plt.title("Test Graph")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
from sklearn.datasets import load_iris

iris = load_iris()

print("Dataset Loaded Successfully!")
print("Number of Samples:", len(iris.data))
print("Number of Features:", len(iris.feature_names))
# Out:
# Dataset Loaded Successfully!
# Number of Samples: 150
# Number of Features: 4
